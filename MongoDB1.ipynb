# %% [markdown]
# <a href="https://colab.research.google.com/github/Kabirxoja/Checkeyesight/blob/master/MongoDB1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymongo --upgrade

# %%
from pymongo import MongoClient

# %%
uri = "mongodb+srv://xakimov3258_db_user:Nv2rMQGAQckfpWXH@cluster0.lyymvwh.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
client = MongoClient(uri, tls=True, tlsAllowInvalidCertificates=True, serverSelectionTimeoutMS=10000)

# %%
db = client["test_db"]

# %%
collection = db["students"]

# %%
try:
    db = client["test_db"]
    collection = db["students"]
    result = collection.insert_one({"name": "Kabirkhoja", "course": "Android"})
    print("✅ Ma'lumot qo'shildi:", result.inserted_id)
except Exception as e:
    print("❌ Xato:", e)
# Out:
# ❌ Xato: SSL handshake failed: ac-mq0rky9-shard-00-01.lyymvwh.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1010) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-mq0rky9-shard-00-02.lyymvwh.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1010) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-mq0rky9-shard-00-00.lyymvwh.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1010) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 10.0s, Topology Description: <TopologyDescription id: 68e64e531481e6b8e61a130b, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-mq0rky9-shard-00-00.lyymvwh.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-mq0rky9-shard-00-00.lyym
# ...

# %% [markdown]
# try exept qoshib qoyibsizku. Baribir xato beryaptiku.Natijasi chiqmaganku xaxaxaxaxa
